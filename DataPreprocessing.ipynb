# %%
# !ls
# Out:
# BuildDeepFaceLab.ipynb	 README.md		     mlsteam.yml
# DataPreprocessing.ipynb  entry.ipynb		     scripts
# DeepFaceLab		 machine-learning-tutorials  workspace

# %%
# !apt install -y ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   i965-va-driver libaacs0 libasound2 libasound2-data libass9 libasyncns0
#   libavc1394-0 libavcodec57 libavdevice57 libavfilter6 libavformat57
#   libavresample3 libavutil55 libbdplus0 libbluray2 libbs2b0 libcaca0
#   libcdio-cdda2 libcdio-paranoia2 libcdio17 libchromaprint1 libcrystalhd3
#   libdc1394-22 libegl-mesa0 libegl1 libfftw3-double3 libflac8 libflite1
#   libfribidi0 libgbm1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgme0 libgsm1 libiec61883-0 libjack-jackd2-0
#   libmp3lame0 libmpg123-0 libmysofa0 libnuma1 libogg0 libopenal-data
#   libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpostproc54 libpulse0
#   libraw1394-11 librsvg2-2 librsvg2-common librubberband2 libsamplerate0
#   libsdl2-2.0-0 libshine3 libslang2 libsnappy1v5 libsndfile1 libsndio6.1
#   libsoxr0 libspeex1 libssh-gcrypt-4 libswresample2 libswscale4 libtheora0
#   libtwolame0 libusb-1.0-0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx5 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwayland-egl1-mesa libwayland-server0
#   libwebp6 libwebpmux3 libx264-152 libx265-146 libxcb-xfixes0 libxkbcommon0
#   libxvidcore4 libzvbi-common libzvbi0 mesa-va-drivers mesa-vdpau-drivers
#   va-driver-all vdpau-driver-all xkb-data
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libasound2-plugins alsa-utils
#   libbluray-bdj firmware-crystalhd libfftw3-bin libfftw3-dev jackd2
#   libportaudio2 opus-tools pulseaudio libraw1394-doc librsvg2-bin sndiod speex
#   libvdpau-va-gl1 nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg i965-va-driver libaacs0 libasound2 libasound2-data libass9
#   libasyncns0 libavc1394-0 libavcodec57 libavdevice57 libavfilter6
#   libavformat57 libavresample3 libavutil55 libbdplus0 libbluray2 libbs2b0
#   libcaca0 libcdio-cdda2 libcdio-paranoia2 libcdio17 libchromaprint1
#   libcrystalhd3 libdc1394-22 libegl-mesa0 libegl1 libfftw3-double3 libflac8
#   libflite1 libfribidi0 libgbm1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgme0 libgsm1 libiec61883-0 libjack-jackd2-0
#   libmp3lame0 libmpg123-0 libmysofa0 libnuma1 libogg0 libopenal-data
#   libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpostproc54 libpulse0
#   libraw1394-11 librsvg2-2 librsvg2-common librubberband2 libsamplerate0
#   libsdl2-2.0-0 libshine3 libslang2 libsnappy1v5 libsndfile1 libsndio6.1
#   libsoxr0 libspeex1 libssh-gcrypt-4 libswresample2 libswscale4 libtheora0
#   libtwolame0 libusb-1.0-0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx5 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwayland-egl1-mesa libwayland-server0
#   libwebp6 libwebpmux3 libx264-152 libx265-146 libxcb-xfixes0 libxkbcommon0
#   libxvidcore4 libzvbi-common libzvbi0 mesa-va-drivers mesa-vdpau-drivers
#   va-driver-all vdpau-driver-all xkb-data
# 0 upgraded, 97 newly installed, 0 to remove and 19 not upgraded.
# Need to get 38.7 MB of archives.
# After this operation, 171 MB of additional disk space will be used.
# Get:1 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libogg0 amd64 1.3.2-1 [17.2 kB]
# Get:2 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libfribidi0 amd64 0.19.7-2 [24.9 kB]
# Get:3 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libslang2 amd64 2.3.1a-3ubuntu1 [424 kB]
# Get:4 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 xkb-data all 2.23.1-1ubuntu1.18.04.1 [325 kB]
# Get:5 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnuma1 amd64 2.0.11-2.1ubuntu0.1 [22.0 kB]
# Get:6 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libusb-1.0-0 amd64 2:1.0.21-2 [43.3 kB]
# Get:7 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libva2 amd64 2.1.0-3 [47.6 kB]
# Get:8 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libva-drm2 amd64 2.1.0-3 [6880 B]
# Get:9 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libva-x11-2 amd64 2.1.0-3 [11.5 kB]
# Get:10 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libvdpau1 amd64 1.1.1-3ubuntu1 [25.5 kB]
# Get:11 http://tw.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavutil55 amd64 7:3.4.8-0ubuntu0.2 [190 kB]
# Get:12 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libcrystalhd3 amd64 1:0.0~git20110715.fdd2f19-12 [45.8 kB]
# Get:13 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libgsm1 amd64 1.0.13-4build1 [22.4 kB]
# Get:14 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libmp3lame0 amd64 3.100-2 [136 kB]
# Get:15 http://tw.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopenjp2-7 amd64 2.3.0-2build0.18.04.1 [145 kB]
# Get:16 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libopus0 amd64 1.1.2-1ubuntu1 [159 kB]
# Get:17 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-common all 2.36.11-2 [4536 B]
# Get:18 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-0 amd64 2.36.11-2 [165 kB]
# Get:19 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 librsvg2-2 amd64 2.40.20-2ubuntu0.2 [98.6 kB]
# Get:20 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libshine3 amd64 3.1.1-1 [22.9 kB]
# Get:21 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libsnappy1v5 amd64 1.1.7-1 [16.0 kB]
# Get:22 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libspeex1 amd64 1.2~rc1.2-1ubuntu2 [52.1 kB]
# Get:23 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libsoxr0 amd64 0.1.2-3 [65.9 kB]
# Get:24 http://tw.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libswresample2 amd64 7:3.4.8-0ubuntu0.2 [55.2 kB]
# Get:25 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libtheora0 amd64 1.1.1+dfsg.1-14 [170 kB]
# Get:26 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libtwolame0 amd64 0.3.13-3 [46.7 kB]
# Get:27 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libvorbis0a amd64 1.3.5-4.2 [86.4 kB]
# Get:28 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libvorbisenc2 amd64 1.3.5-4.2 [70.7 kB]
# Get:29 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libvpx5 amd64 1.7.0-3ubuntu0.18.04.1 [796 kB]
# Get:30 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwavpack1 amd64 5.1.0-2ubuntu1.5 [76.8 kB]
# Get:31 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libwebp6 amd64 0.6.1-2 [185 kB]
# Get:32 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libwebpmux3 amd64 0.6.1-2 [19.6 kB]
# Get:33 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libx264-152 amd64 2:0.152.2854+gite9a5903-2 [609 kB]
# Get:34 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libx265-146 amd64 2.6-3 [1026 kB]
# Get:35 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libxvidcore4 amd64 2:1.3.5-1 [200 kB]
# Get:36 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libzvbi-common all 0.2.35-13 [32.1 kB]
# Get:37 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libzvbi0 amd64 0.2.35-13 [235 kB]
# Get:38 http://tw.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavcodec57 amd64 7:3.4.8-0ubuntu0.2 [4595 kB]
# Get:39 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libasound2-data all 1.1.3-5ubuntu0.5 [38.7 kB]
# Get:40 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libasound2 amd64 1.1.3-5ubuntu0.5 [360 kB]
# Get:41 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libraw1394-11 amd64 2.1.2-1 [30.7 kB]
# Get:42 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libavc1394-0 amd64 0.5.4-4build1 [16.1 kB]
# Get:43 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libass9 amd64 1:0.14.0-1 [88.2 kB]
# Get:44 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libbluray2 amd64 1:1.0.2-3 [141 kB]
# Get:45 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libchromaprint1 amd64 1.4.3-1 [36.8 kB]
# Get:46 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libgme0 amd64 0.6.2-1 [121 kB]
# Get:47 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libmpg123-0 amd64 1.25.10-1 [125 kB]
# Get:48 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libvorbisfile3 amd64 1.3.5-4.2 [16.0 kB]
# Get:49 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libopenmpt0 amd64 0.3.6-1 [561 kB]
# Get:50 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libssh-gcrypt-4 amd64 0.8.0~20170825.94fa1e38-1ubuntu0.7 [172 kB]
# Get:51 http://tw.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavformat57 amd64 7:3.4.8-0ubuntu0.2 [953 kB]
# Get:52 http://tw.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavresample3 amd64 7:3.4.8-0ubuntu0.2 [52.6 kB]
# Get:53 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libbs2b0 amd64 3.1.0+dfsg-2.2 [10.5 kB]
# Get:54 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libflite1 amd64 2.1-release-1 [12.8 MB]
# Get:55 http://tw.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libmysofa0 amd64 0.6~dfsg0-3+deb10u1build1 [38.5 kB]
# Get:56 http://tw.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpostproc54 amd64 7:3.4.8-0ubuntu0.2 [50.3 kB]
# Get:57 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-double3 amd64 3.3.7-1 [735 kB]
# Get:58 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libsamplerate0 amd64 0.1.9-1 [938 kB]
# Get:59 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 librubberband2 amd64 1.8.1-7ubuntu2 [86.7 kB]
# Get:60 http://tw.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libswscale4 amd64 7:3.4.8-0ubuntu0.2 [150 kB]
# Get:61 http://tw.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavfilter6 amd64 7:3.4.8-0ubuntu0.2 [874 kB]
# Get:62 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcaca0 amd64 0.99.beta19-2ubuntu0.18.04.1 [203 kB]
# Get:63 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libcdio17 amd64 1.0.0-2ubuntu2 [58.8 kB]
# Get:64 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libcdio-cdda2 amd64 10.2+0.94+2-2build1 [17.7 kB]
# Get:65 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libcdio-paranoia2 amd64 10.2+0.94+2-2build1 [17.2 kB]
# Get:66 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libdc1394-22 amd64 2.2.5-1 [77.5 kB]
# Get:67 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libiec61883-0 amd64 1.2.0-2 [23.5 kB]
# Get:68 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libjack-jackd2-0 amd64 1.9.12~dfsg-2 [263 kB]
# Get:69 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libopenal-data all 1:1.18.2-2 [102 kB]
# Get:70 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libsndio6.1 amd64 1.1.0-3 [23.4 kB]
# Get:71 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libopenal1 amd64 1:1.18.2-2 [266 kB]
# Get:72 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libasyncns0 amd64 0.8-6 [12.1 kB]
# Get:73 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libflac8 amd64 1.3.2-1 [213 kB]
# Get:74 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsndfile1 amd64 1.0.28-4ubuntu0.18.04.1 [170 kB]
# Get:75 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse0 amd64 1:11.1-1ubuntu7.11 [266 kB]
# Get:76 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwayland-client0 amd64 1.16.0-1ubuntu1.1~18.04.3 [23.6 kB]
# Get:77 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwayland-cursor0 amd64 1.16.0-1ubuntu1.1~18.04.3 [10.1 kB]
# Get:78 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwayland-server0 amd64 1.16.0-1ubuntu1.1~18.04.3 [29.6 kB]
# Get:79 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgbm1 amd64 20.0.8-0ubuntu1~18.04.1 [27.6 kB]
# Get:80 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-xfixes0 amd64 1.13-2~ubuntu18.04 [9352 B]
# Get:81 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libegl-mesa0 amd64 20.0.8-0ubuntu1~18.04.1 [96.3 kB]
# Get:82 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libegl1 amd64 1.0.0-2ubuntu2.3 [32.0 kB]
# Get:83 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwayland-egl1 amd64 1.16.0-1ubuntu1.1~18.04.3 [5464 B]
# Get:84 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwayland-egl1-mesa amd64 20.0.8-0ubuntu1~18.04.1 [6444 B]
# Get:85 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxkbcommon0 amd64 0.8.2-1~ubuntu18.04.1 [97.8 kB]
# Get:86 http://tw.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsdl2-2.0-0 amd64 2.0.8+dfsg1-1ubuntu1.18.04.4 [382 kB]
# Get:87 http://tw.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavdevice57 amd64 7:3.4.8-0ubuntu0.2 [74.9 kB]
# Get:88 http://tw.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 ffmpeg amd64 7:3.4.8-0ubuntu0.2 [1587 kB]
# Get:89 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libaacs0 amd64 0.9.0-1 [51.4 kB]
# Get:90 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 libbdplus0 amd64 0.1.2-2 [46.6 kB]
# Get:91 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-bin amd64 2.36.11-2 [7864 B]
# Get:92 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 librsvg2-common amd64 2.40.20-2ubuntu0.2 [5064 B]
# Get:93 http://tw.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 mesa-va-drivers amd64 20.0.8-0ubuntu1~18.04.1 [2376 kB]
# Get:94 http://tw.archive.ubuntu.com/ubuntu bionic-updates/main amd64 mesa-vdpau-drivers amd64 20.0.8-0ubuntu1~18.04.1 [2496 kB]
# Get:95 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 i965-va-driver amd64 2.1.0-0ubuntu1 [925 kB]
# Get:96 http://tw.archive.ubuntu.com/ubuntu bionic/universe amd64 va-driver-all amd64 2.1.0-3 [4376 B]
# Get:97 http://tw.archive.ubuntu.com/ubuntu bionic/main amd64 vdpau-driver-all amd64 1.1.1-3ubuntu1 [4674 B]
# Fetched 38.7 MB in 1s (36.6 MB/s)
# perl: warning: Setting locale failed.
# perl: warning: Please check that your locale settings:
# 	LANGUAGE = "en.UTF-8",
# 	LC_ALL = (unset),
# 	LANG = "en.UTF-8"
#     are supported and installed on your system.
# perl: warning: Falling back to the standard locale ("C").
# locale: Cannot set LC_CTYPE to default locale: No such file or directory
# locale: Cannot set LC_MESSAGES to default locale: No such file or directory
# locale: Cannot set LC_ALL to default locale: No such file or directory
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package libogg0:amd64.
# (Reading database ... 34959 files and directories currently installed.)
# Preparing to unpack .../00-libogg0_1.3.2-1_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libogg0:amd64 (1.3.2-1) ...
# Selecting previously unselected package libfribidi0:amd64.
# Preparing to unpack .../01-libfribidi0_0.19.7-2_amd64.deb ...
# Unpacking libfribidi0:amd64 (0.19.7-2) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libslang2:amd64.
# Preparing to unpack .../02-libslang2_2.3.1a-3ubuntu1_amd64.deb ...
# Unpacking libslang2:amd64 (2.3.1a-3ubuntu1) ...
# Selecting previously unselected package xkb-data.
# Preparing to unpack .../03-xkb-data_2.23.1-1ubuntu1.18.04.1_all.deb ...
# 7Progress: [  2%] [#.........................................................] 8Unpacking xkb-data (2.23.1-1ubuntu1.18.04.1) ...
# Selecting previously unselected package libnuma1:amd64.
# Preparing to unpack .../04-libnuma1_2.0.11-2.1ubuntu0.1_amd64.deb ...
# Unpacking libnuma1:amd64 (2.0.11-2.1ubuntu0.1) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libusb-1.0-0:amd64.
# Preparing to unpack .../05-libusb-1.0-0_2%3a1.0.21-2_amd64.deb ...
# Unpacking libusb-1.0-0:amd64 (2:1.0.21-2) ...
# Selecting previously unselected package libva2:amd64.
# Preparing to unpack .../06-libva2_2.1.0-3_amd64.deb ...
# Unpacking libva2:amd64 (2.1.0-3) ...
# 7Progress: [  4%] [##........................................................] 8Selecting previously unselected package libva-drm2:amd64.
# Preparing to unpack .../07-libva-drm2_2.1.0-3_amd64.deb ...
# Unpacking libva-drm2:amd64 (2.1.0-3) ...
# Selecting previously unselected package libva-x11-2:amd64.
# Preparing to unpack .../08-libva-x11-2_2.1.0-3_amd64.deb ...
# 7Progress: [  5%] [##........................................................] 8Unpacking libva-x11-2:amd64 (2.1.0-3) ...
# Selecting previously unselected package libvdpau1:amd64.
# Preparing to unpack .../09-libvdpau1_1.1.1-3ubuntu1_amd64.deb ...
# Unpacking libvdpau1:amd64 (1.1.1-3ubuntu1) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package libavutil55:amd64.
# Preparing to unpack .../10-libavutil55_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libavutil55:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package libcrystalhd3:amd64.
# Preparing to unpack .../11-libcrystalhd3_1%3a0.0~git20110715.fdd2f19-12_amd64.deb ...
# Unpacking libcrystalhd3:amd64 (1:0.0~git20110715.fdd2f19-12) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package libgsm1:amd64.
# Preparing to unpack .../12-libgsm1_1.0.13-4build1_amd64.deb ...
# Unpacking libgsm1:amd64 (1.0.13-4build1) ...
# 7Progress: [  8%] [####......................................................] 8Selecting previously unselected package libmp3lame0:amd64.
# Preparing to unpack .../13-libmp3lame0_3.100-2_amd64.deb ...
# Unpacking libmp3lame0:amd64 (3.100-2) ...
# Selecting previously unselected package libopenjp2-7:amd64.
# Preparing to unpack .../14-libopenjp2-7_2.3.0-2build0.18.04.1_amd64.deb ...
# Unpacking libopenjp2-7:amd64 (2.3.0-2build0.18.04.1) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package libopus0:amd64.
# Preparing to unpack .../15-libopus0_1.1.2-1ubuntu1_amd64.deb ...
# Unpacking libopus0:amd64 (1.1.2-1ubuntu1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-common.
# Preparing to unpack .../16-libgdk-pixbuf2.0-common_2.36.11-2_all.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libgdk-pixbuf2.0-common (2.36.11-2) ...
# Selecting previously unselected package libgdk-pixbuf2.0-0:amd64.
# Preparing to unpack .../17-libgdk-pixbuf2.0-0_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
# 7Progress: [ 11%] [######....................................................] 8Selecting previously unselected package librsvg2-2:amd64.
# Preparing to unpack .../18-librsvg2-2_2.40.20-2ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-2:amd64 (2.40.20-2ubuntu0.2) ...
# Selecting previously unselected package libshine3:amd64.
# Preparing to unpack .../19-libshine3_3.1.1-1_amd64.deb ...
# Unpacking libshine3:amd64 (3.1.1-1) ...
# 7Progress: [ 12%] [#######...................................................] 8Selecting previously unselected package libsnappy1v5:amd64.
# Preparing to unpack .../20-libsnappy1v5_1.1.7-1_amd64.deb ...
# Unpacking libsnappy1v5:amd64 (1.1.7-1) ...
# Selecting previously unselected package libspeex1:amd64.
# Preparing to unpack .../21-libspeex1_1.2~rc1.2-1ubuntu2_amd64.deb ...
# 7Progress: [ 13%] [#######...................................................] 8Unpacking libspeex1:amd64 (1.2~rc1.2-1ubuntu2) ...
# Selecting previously unselected package libsoxr0:amd64.
# Preparing to unpack .../22-libsoxr0_0.1.2-3_amd64.deb ...
# Unpacking libsoxr0:amd64 (0.1.2-3) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package libswresample2:amd64.
# Preparing to unpack .../23-libswresample2_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libswresample2:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package libtheora0:amd64.
# Preparing to unpack .../24-libtheora0_1.1.1+dfsg.1-14_amd64.deb ...
# 7Progress: [ 15%] [########..................................................] 8Unpacking libtheora0:amd64 (1.1.1+dfsg.1-14) ...
# Selecting previously unselected package libtwolame0:amd64.
# Preparing to unpack .../25-libtwolame0_0.3.13-3_amd64.deb ...
# Unpacking libtwolame0:amd64 (0.3.13-3) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libvorbis0a:amd64.
# Preparing to unpack .../26-libvorbis0a_1.3.5-4.2_amd64.deb ...
# Unpacking libvorbis0a:amd64 (1.3.5-4.2) ...
# Selecting previously unselected package libvorbisenc2:amd64.
# Preparing to unpack .../27-libvorbisenc2_1.3.5-4.2_amd64.deb ...
# Unpacking libvorbisenc2:amd64 (1.3.5-4.2) ...
# 7Progress: [ 17%] [#########.................................................] 8Selecting previously unselected package libvpx5:amd64.
# Preparing to unpack .../28-libvpx5_1.7.0-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libvpx5:amd64 (1.7.0-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../29-libwavpack1_5.1.0-2ubuntu1.5_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libwavpack1:amd64 (5.1.0-2ubuntu1.5) ...
# Selecting previously unselected package libwebp6:amd64.
# Preparing to unpack .../30-libwebp6_0.6.1-2_amd64.deb ...
# Unpacking libwebp6:amd64 (0.6.1-2) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libwebpmux3:amd64.
# Preparing to unpack .../31-libwebpmux3_0.6.1-2_amd64.deb ...
# Unpacking libwebpmux3:amd64 (0.6.1-2) ...
# Selecting previously unselected package libx264-152:amd64.
# Preparing to unpack .../32-libx264-152_2%3a0.152.2854+gite9a5903-2_amd64.deb ...
# Unpacking libx264-152:amd64 (2:0.152.2854+gite9a5903-2) ...
# 7Progress: [ 20%] [###########...............................................] 8Selecting previously unselected package libx265-146:amd64.
# Preparing to unpack .../33-libx265-146_2.6-3_amd64.deb ...
# Unpacking libx265-146:amd64 (2.6-3) ...
# Selecting previously unselected package libxvidcore4:amd64.
# Preparing to unpack .../34-libxvidcore4_2%3a1.3.5-1_amd64.deb ...
# 7Progress: [ 21%] [############..............................................] 8Unpacking libxvidcore4:amd64 (2:1.3.5-1) ...
# Selecting previously unselected package libzvbi-common.
# Preparing to unpack .../35-libzvbi-common_0.2.35-13_all.deb ...
# Unpacking libzvbi-common (0.2.35-13) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package libzvbi0:amd64.
# Preparing to unpack .../36-libzvbi0_0.2.35-13_amd64.deb ...
# Unpacking libzvbi0:amd64 (0.2.35-13) ...
# Selecting previously unselected package libavcodec57:amd64.
# Preparing to unpack .../37-libavcodec57_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking libavcodec57:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package libasound2-data.
# Preparing to unpack .../38-libasound2-data_1.1.3-5ubuntu0.5_all.deb ...
# Unpacking libasound2-data (1.1.3-5ubuntu0.5) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libasound2:amd64.
# Preparing to unpack .../39-libasound2_1.1.3-5ubuntu0.5_amd64.deb ...
# Unpacking libasound2:amd64 (1.1.3-5ubuntu0.5) ...
# Selecting previously unselected package libraw1394-11:amd64.
# Preparing to unpack .../40-libraw1394-11_2.1.2-1_amd64.deb ...
# Unpacking libraw1394-11:amd64 (2.1.2-1) ...
# 7Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libavc1394-0:amd64.
# Preparing to unpack .../41-libavc1394-0_0.5.4-4build1_amd64.deb ...
# Unpacking libavc1394-0:amd64 (0.5.4-4build1) ...
# Selecting previously unselected package libass9:amd64.
# Preparing to unpack .../42-libass9_1%3a0.14.0-1_amd64.deb ...
# 7Progress: [ 26%] [###############...........................................] 8Unpacking libass9:amd64 (1:0.14.0-1) ...
# Selecting previously unselected package libbluray2:amd64.
# Preparing to unpack .../43-libbluray2_1%3a1.0.2-3_amd64.deb ...
# Unpacking libbluray2:amd64 (1:1.0.2-3) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libchromaprint1:amd64.
# Preparing to unpack .../44-libchromaprint1_1.4.3-1_amd64.deb ...
# Unpacking libchromaprint1:amd64 (1.4.3-1) ...
# Selecting previously unselected package libgme0:amd64.
# Preparing to unpack .../45-libgme0_0.6.2-1_amd64.deb ...
# Unpacking libgme0:amd64 (0.6.2-1) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libmpg123-0:amd64.
# Preparing to unpack .../46-libmpg123-0_1.25.10-1_amd64.deb ...
# Unpacking libmpg123-0:amd64 (1.25.10-1) ...
# 7Progress: [ 29%] [################..........................................] 8Selecting previously unselected package libvorbisfile3:amd64.
# Preparing to unpack .../47-libvorbisfile3_1.3.5-4.2_amd64.deb ...
# Unpacking libvorbisfile3:amd64 (1.3.5-4.2) ...
# Selecting previously unselected package libopenmpt0:amd64.
# Preparing to unpack .../48-libopenmpt0_0.3.6-1_amd64.deb ...
# Unpacking libopenmpt0:amd64 (0.3.6-1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libssh-gcrypt-4:amd64.
# Preparing to unpack .../49-libssh-gcrypt-4_0.8.0~20170825.94fa1e38-1ubuntu0.7_amd64.deb ...
# Unpacking libssh-gcrypt-4:amd64 (0.8.0~20170825.94fa1e38-1ubuntu0.7) ...
# Selecting previously unselected package libavformat57:amd64.
# Preparing to unpack .../50-libavformat57_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# 7Progress: [ 31%] [##################........................................] 8Unpacking libavformat57:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package libavresample3:amd64.
# Preparing to unpack .../51-libavresample3_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libavresample3:amd64 (7:3.4.8-0ubuntu0.2) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libbs2b0:amd64.
# Preparing to unpack .../52-libbs2b0_3.1.0+dfsg-2.2_amd64.deb ...
# Unpacking libbs2b0:amd64 (3.1.0+dfsg-2.2) ...
# Selecting previously unselected package libflite1:amd64.
# Preparing to unpack .../53-libflite1_2.1-release-1_amd64.deb ...
# Unpacking libflite1:amd64 (2.1-release-1) ...
# 7Progress: [ 33%] [###################.......................................] 8Selecting previously unselected package libmysofa0:amd64.
# Preparing to unpack .../54-libmysofa0_0.6~dfsg0-3+deb10u1build1_amd64.deb ...
# Unpacking libmysofa0:amd64 (0.6~dfsg0-3+deb10u1build1) ...
# Selecting previously unselected package libpostproc54:amd64.
# Preparing to unpack .../55-libpostproc54_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking libpostproc54:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package libfftw3-double3:amd64.
# Preparing to unpack .../56-libfftw3-double3_3.3.7-1_amd64.deb ...
# Unpacking libfftw3-double3:amd64 (3.3.7-1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libsamplerate0:amd64.
# Preparing to unpack .../57-libsamplerate0_0.1.9-1_amd64.deb ...
# Unpacking libsamplerate0:amd64 (0.1.9-1) ...
# Selecting previously unselected package librubberband2:amd64.
# Preparing to unpack .../58-librubberband2_1.8.1-7ubuntu2_amd64.deb ...
# 7Progress: [ 36%] [####################......................................] 8Unpacking librubberband2:amd64 (1.8.1-7ubuntu2) ...
# Selecting previously unselected package libswscale4:amd64.
# Preparing to unpack .../59-libswscale4_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libswscale4:amd64 (7:3.4.8-0ubuntu0.2) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libavfilter6:amd64.
# Preparing to unpack .../60-libavfilter6_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libavfilter6:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package libcaca0:amd64.
# Preparing to unpack .../61-libcaca0_0.99.beta19-2ubuntu0.18.04.1_amd64.deb ...
# Unpacking libcaca0:amd64 (0.99.beta19-2ubuntu0.18.04.1) ...
# 7Progress: [ 38%] [######################....................................] 8Selecting previously unselected package libcdio17:amd64.
# Preparing to unpack .../62-libcdio17_1.0.0-2ubuntu2_amd64.deb ...
# Unpacking libcdio17:amd64 (1.0.0-2ubuntu2) ...
# Selecting previously unselected package libcdio-cdda2:amd64.
# Preparing to unpack .../63-libcdio-cdda2_10.2+0.94+2-2build1_amd64.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking libcdio-cdda2:amd64 (10.2+0.94+2-2build1) ...
# Selecting previously unselected package libcdio-paranoia2:amd64.
# Preparing to unpack .../64-libcdio-paranoia2_10.2+0.94+2-2build1_amd64.deb ...
# Unpacking libcdio-paranoia2:amd64 (10.2+0.94+2-2build1) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package libdc1394-22:amd64.
# Preparing to unpack .../65-libdc1394-22_2.2.5-1_amd64.deb ...
# Unpacking libdc1394-22:amd64 (2.2.5-1) ...
# Selecting previously unselected package libiec61883-0:amd64.
# Preparing to unpack .../66-libiec61883-0_1.2.0-2_amd64.deb ...
# Unpacking libiec61883-0:amd64 (1.2.0-2) ...
# 7Progress: [ 41%] [#######################...................................] 8Selecting previously unselected package libjack-jackd2-0:amd64.
# Preparing to unpack .../67-libjack-jackd2-0_1.9.12~dfsg-2_amd64.deb ...
# Unpacking libjack-jackd2-0:amd64 (1.9.12~dfsg-2) ...
# Selecting previously unselected package libopenal-data.
# Preparing to unpack .../68-libopenal-data_1%3a1.18.2-2_all.deb ...
# 7Progress: [ 42%] [########################..................................] 8Unpacking libopenal-data (1:1.18.2-2) ...
# Selecting previously unselected package libsndio6.1:amd64.
# Preparing to unpack .../69-libsndio6.1_1.1.0-3_amd64.deb ...
# Unpacking libsndio6.1:amd64 (1.1.0-3) ...
# 7Progress: [ 43%] [########################..................................] 8Selecting previously unselected package libopenal1:amd64.
# Preparing to unpack .../70-libopenal1_1%3a1.18.2-2_amd64.deb ...
# Unpacking libopenal1:amd64 (1:1.18.2-2) ...
# Selecting previously unselected package libasyncns0:amd64.
# Preparing to unpack .../71-libasyncns0_0.8-6_amd64.deb ...
# 7Progress: [ 44%] [#########################.................................] 8Unpacking libasyncns0:amd64 (0.8-6) ...
# Selecting previously unselected package libflac8:amd64.
# Preparing to unpack .../72-libflac8_1.3.2-1_amd64.deb ...
# Unpacking libflac8:amd64 (1.3.2-1) ...
# 7Progress: [ 45%] [##########################................................] 8Selecting previously unselected package libsndfile1:amd64.
# Preparing to unpack .../73-libsndfile1_1.0.28-4ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsndfile1:amd64 (1.0.28-4ubuntu0.18.04.1) ...
# Selecting previously unselected package libpulse0:amd64.
# Preparing to unpack .../74-libpulse0_1%3a11.1-1ubuntu7.11_amd64.deb ...
# Unpacking libpulse0:amd64 (1:11.1-1ubuntu7.11) ...
# 7Progress: [ 46%] [##########################................................] 8Selecting previously unselected package libwayland-client0:amd64.
# Preparing to unpack .../75-libwayland-client0_1.16.0-1ubuntu1.1~18.04.3_amd64.deb ...
# Unpacking libwayland-client0:amd64 (1.16.0-1ubuntu1.1~18.04.3) ...
# Selecting previously unselected package libwayland-cursor0:amd64.
# Preparing to unpack .../76-libwayland-cursor0_1.16.0-1ubuntu1.1~18.04.3_amd64.deb ...
# 7Progress: [ 47%] [###########################...............................] 8Unpacking libwayland-cursor0:amd64 (1.16.0-1ubuntu1.1~18.04.3) ...
# Selecting previously unselected package libwayland-server0:amd64.
# Preparing to unpack .../77-libwayland-server0_1.16.0-1ubuntu1.1~18.04.3_amd64.deb ...
# Unpacking libwayland-server0:amd64 (1.16.0-1ubuntu1.1~18.04.3) ...
# 7Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package libgbm1:amd64.
# Preparing to unpack .../78-libgbm1_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgbm1:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libxcb-xfixes0:amd64.
# Preparing to unpack .../79-libxcb-xfixes0_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-xfixes0:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 49%] [############################..............................] 8Selecting previously unselected package libegl-mesa0:amd64.
# Preparing to unpack .../80-libegl-mesa0_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libegl-mesa0:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# 7Progress: [ 50%] [#############################.............................] 8Selecting previously unselected package libegl1:amd64.
# Preparing to unpack .../81-libegl1_1.0.0-2ubuntu2.3_amd64.deb ...
# Unpacking libegl1:amd64 (1.0.0-2ubuntu2.3) ...
# Selecting previously unselected package libwayland-egl1:amd64.
# Preparing to unpack .../82-libwayland-egl1_1.16.0-1ubuntu1.1~18.04.3_amd64.deb ...
# Unpacking libwayland-egl1:amd64 (1.16.0-1ubuntu1.1~18.04.3) ...
# 7Progress: [ 51%] [#############################.............................] 8Selecting previously unselected package libwayland-egl1-mesa:amd64.
# Preparing to unpack .../83-libwayland-egl1-mesa_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libwayland-egl1-mesa:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libxkbcommon0:amd64.
# Preparing to unpack .../84-libxkbcommon0_0.8.2-1~ubuntu18.04.1_amd64.deb ...
# 7Progress: [ 52%] [##############################............................] 8Unpacking libxkbcommon0:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Selecting previously unselected package libsdl2-2.0-0:amd64.
# Preparing to unpack .../85-libsdl2-2.0-0_2.0.8+dfsg1-1ubuntu1.18.04.4_amd64.deb ...
# Unpacking libsdl2-2.0-0:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# 7Progress: [ 53%] [##############################............................] 8Selecting previously unselected package libavdevice57:amd64.
# Preparing to unpack .../86-libavdevice57_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking libavdevice57:amd64 (7:3.4.8-0ubuntu0.2) ...
# Selecting previously unselected package ffmpeg.
# Preparing to unpack .../87-ffmpeg_7%3a3.4.8-0ubuntu0.2_amd64.deb ...
# Unpacking ffmpeg (7:3.4.8-0ubuntu0.2) ...
# 7Progress: [ 54%] [###############################...........................] 8Selecting previously unselected package libaacs0:amd64.
# Preparing to unpack .../88-libaacs0_0.9.0-1_amd64.deb ...
# Unpacking libaacs0:amd64 (0.9.0-1) ...
# Selecting previously unselected package libbdplus0:amd64.
# Preparing to unpack .../89-libbdplus0_0.1.2-2_amd64.deb ...
# 7Progress: [ 55%] [###############################...........................] 8Unpacking libbdplus0:amd64 (0.1.2-2) ...
# Selecting previously unselected package libgdk-pixbuf2.0-bin.
# Preparing to unpack .../90-libgdk-pixbuf2.0-bin_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-bin (2.36.11-2) ...
# 7Progress: [ 56%] [################################..........................] 8Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../91-librsvg2-common_2.40.20-2ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.40.20-2ubuntu0.2) ...
# Selecting previously unselected package mesa-va-drivers:amd64.
# Preparing to unpack .../92-mesa-va-drivers_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking mesa-va-drivers:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# 7Progress: [ 57%] [#################################.........................] 8Selecting previously unselected package mesa-vdpau-drivers:amd64.
# Preparing to unpack .../93-mesa-vdpau-drivers_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking mesa-vdpau-drivers:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# 7Progress: [ 58%] [#################################.........................] 8Selecting previously unselected package i965-va-driver:amd64.
# Preparing to unpack .../94-i965-va-driver_2.1.0-0ubuntu1_amd64.deb ...
# Unpacking i965-va-driver:amd64 (2.1.0-0ubuntu1) ...
# Selecting previously unselected package va-driver-all:amd64.
# Preparing to unpack .../95-va-driver-all_2.1.0-3_amd64.deb ...
# Unpacking va-driver-all:amd64 (2.1.0-3) ...
# 7Progress: [ 59%] [##################################........................] 8Selecting previously unselected package vdpau-driver-all:amd64.
# Preparing to unpack .../96-vdpau-driver-all_1.1.1-3ubuntu1_amd64.deb ...
# Unpacking vdpau-driver-all:amd64 (1.1.1-3ubuntu1) ...
# Setting up libtwolame0:amd64 (0.3.13-3) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libraw1394-11:amd64 (2.1.2-1) ...
# Setting up libx264-152:amd64 (2:0.152.2854+gite9a5903-2) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libxcb-xfixes0:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libopenjp2-7:amd64 (2.3.0-2build0.18.04.1) ...
# Setting up libasyncns0:amd64 (0.8-6) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libwavpack1:amd64 (5.1.0-2ubuntu1.5) ...
# Setting up libaacs0:amd64 (0.9.0-1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libnuma1:amd64 (2.0.11-2.1ubuntu0.1) ...
# Setting up libsoxr0:amd64 (0.1.2-3) ...
# Setting up libssh-gcrypt-4:amd64 (0.8.0~20170825.94fa1e38-1ubuntu0.7) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libasound2-data (1.1.3-5ubuntu0.5) ...
# Setting up libwayland-client0:amd64 (1.16.0-1ubuntu1.1~18.04.3) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up xkb-data (2.23.1-1ubuntu1.18.04.1) ...
# Setting up libbluray2:amd64 (1:1.0.2-3) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libvdpau1:amd64 (1.1.1-3ubuntu1) ...
# Setting up libgdk-pixbuf2.0-common (2.36.11-2) ...
# Setting up libshine3:amd64 (3.1.1-1) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up libva2:amd64 (2.1.0-3) ...
# Setting up libiec61883-0:amd64 (1.2.0-2) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libspeex1:amd64 (1.2~rc1.2-1ubuntu2) ...
# Setting up libfftw3-double3:amd64 (3.3.7-1) ...
# Setting up libxvidcore4:amd64 (2:1.3.5-1) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up libopus0:amd64 (1.1.2-1ubuntu1) ...
# Setting up libx265-146:amd64 (2.6-3) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libasound2:amd64 (1.1.3-5ubuntu0.5) ...
# Setting up libopenal-data (1:1.18.2-2) ...
# Setting up libbs2b0:amd64 (3.1.0+dfsg-2.2) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libogg0:amd64 (1.3.2-1) ...
# Setting up i965-va-driver:amd64 (2.1.0-0ubuntu1) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libmp3lame0:amd64 (3.100-2) ...
# Setting up libusb-1.0-0:amd64 (2:1.0.21-2) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libcrystalhd3:amd64 (1:0.0~git20110715.fdd2f19-12) ...
# Setting up libsnappy1v5:amd64 (1.1.7-1) ...
# Setting up mesa-va-drivers:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# 7Progress: [ 74%] [##########################################................] 8Setting up libva-drm2:amd64 (2.1.0-3) ...
# Setting up libavc1394-0:amd64 (0.5.4-4build1) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libzvbi-common (0.2.35-13) ...
# Setting up libfribidi0:amd64 (0.19.7-2) ...
# Setting up libxkbcommon0:amd64 (0.8.2-1~ubuntu18.04.1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libvpx5:amd64 (1.7.0-3ubuntu0.18.04.1) ...
# Setting up libgme0:amd64 (0.6.2-1) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libbdplus0:amd64 (0.1.2-2) ...
# Setting up libzvbi0:amd64 (0.2.35-13) ...
# Setting up libva-x11-2:amd64 (2.1.0-3) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libsamplerate0:amd64 (0.1.9-1) ...
# Setting up libsndio6.1:amd64 (1.1.0-3) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libvorbis0a:amd64 (1.3.5-4.2) ...
# Setting up libtheora0:amd64 (1.1.1+dfsg.1-14) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libmpg123-0:amd64 (1.25.10-1) ...
# Setting up libslang2:amd64 (2.3.1a-3ubuntu1) ...
# Setting up libwayland-cursor0:amd64 (1.16.0-1ubuntu1.1~18.04.3) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libgsm1:amd64 (1.0.13-4build1) ...
# Setting up libmysofa0:amd64 (0.6~dfsg0-3+deb10u1build1) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libwayland-egl1:amd64 (1.16.0-1ubuntu1.1~18.04.3) ...
# Setting up libcdio17:amd64 (1.0.0-2ubuntu2) ...
# Setting up libwayland-server0:amd64 (1.16.0-1ubuntu1.1~18.04.3) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libwebp6:amd64 (0.6.1-2) ...
# Setting up libvorbisfile3:amd64 (1.3.5-4.2) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libavutil55:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up libopenmpt0:amd64 (0.3.6-1) ...
# Setting up libflite1:amd64 (2.1-release-1) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up mesa-vdpau-drivers:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up libgbm1:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up libass9:amd64 (1:0.14.0-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libflac8:amd64 (1.3.2-1) ...
# Setting up libgdk-pixbuf2.0-bin (2.36.11-2) ...
# Setting up libdc1394-22:amd64 (2.2.5-1) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libcdio-cdda2:amd64 (10.2+0.94+2-2build1) ...
# Setting up libswresample2:amd64 (7:3.4.8-0ubuntu0.2) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up librubberband2:amd64 (1.8.1-7ubuntu2) ...
# Setting up libswscale4:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up libwebpmux3:amd64 (0.6.1-2) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up va-driver-all:amd64 (2.1.0-3) ...
# Setting up libcdio-paranoia2:amd64 (10.2+0.94+2-2build1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libpostproc54:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up libjack-jackd2-0:amd64 (1.9.12~dfsg-2) ...
# Setting up libopenal1:amd64 (1:1.18.2-2) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libegl-mesa0:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up libvorbisenc2:amd64 (1.3.5-4.2) ...
# 7Progress: [ 93%] [#####################################################.....] 8Setting up libcaca0:amd64 (0.99.beta19-2ubuntu0.18.04.1) ...
# Setting up vdpau-driver-all:amd64 (1.1.1-3ubuntu1) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up librsvg2-2:amd64 (2.40.20-2ubuntu0.2) ...
# Setting up libavresample3:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up libavcodec57:amd64 (7:3.4.8-0ubuntu0.2) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up librsvg2-common:amd64 (2.40.20-2ubuntu0.2) ...
# Setting up libsndfile1:amd64 (1.0.28-4ubuntu0.18.04.1) ...
# Setting up libegl1:amd64 (1.0.0-2ubuntu2.3) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libwayland-egl1-mesa:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up libchromaprint1:amd64 (1.4.3-1) ...
# Setting up libpulse0:amd64 (1:11.1-1ubuntu7.11) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up libsdl2-2.0-0:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Setting up libavformat57:amd64 (7:3.4.8-0ubuntu0.2) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up libavfilter6:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up libavdevice57:amd64 (7:3.4.8-0ubuntu0.2) ...
# Setting up ffmpeg (7:3.4.8-0ubuntu0.2) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
#
# 78

# %%
import os
os.chdir("scripts")

# %%
# !ls
# Out:
# 1_clear_workspace.sh
# 2_extract_image_from_data_src.sh
# 3.1_denoise_data_dst_images.sh
# 3_extract_image_from_data_dst.sh
# 4.1_download_CelebA.sh
# 4.1_download_FFHQ.sh
# 4.1_download_Quick96.sh
# 4.2_data_src_sort.sh
# 4.2_data_src_util_add_landmarks_debug_images.sh
# 4.2_data_src_util_faceset_enhance.sh
# 4.2_data_src_util_faceset_metadata_restore.sh
# 4.2_data_src_util_faceset_metadata_save.sh
# 4.2_data_src_util_faceset_pack.sh
# 4.2_data_src_util_faceset_unpack.sh
# 4.2_data_src_util_recover_original_filename.sh
# 4_data_src_extract_faces_MANUAL.sh
# 4_data_src_extract_faces_S3FD.sh
# 5.2_data_dst_sort.sh
# 5.2_data_dst_util_faceset_pack.sh
# 5.2_data_dst_util_faceset_unpack.sh
# 5.2_data_dst_util_recover_original_filename.sh
# 5_XSeg_data_dst_mask_apply.sh
# 5_XSeg_data_dst_mask_edit.sh
# 5_XSeg_data_dst_mask_fetch.sh
# 5_XSeg_data_dst_mask_remove.sh
# 5_XSeg_data_dst_trained_mask_remove.sh
# 5_XSeg_data_src_mask_apply.sh
# 5_XSeg_data_src_mask_edit.sh
# 5_XSeg_data_src_mask_fetch.sh
# 5_XSeg_data_src_mask_remove.sh
# 5_XSeg_data_src_trained_mask_remove.sh
# 5_XSeg_train.sh
# 5_data_dst_extract_faces_MANUAL.sh
# 5_data_dst_extract_faces_MANUAL_RE-EXTRACT_DELETED_ALIGNED_DEBUG.sh
# 5_data_dst_extract_faces_S3FD.sh
# 5_data_dst_extract_faces_S3FD_+_manual_fix.sh
# 6_train_Quick96.sh
# 6_train_Quick96_no_preview.sh
# 6_train_SAEHD.sh
# 6_train_SAEHD_no_preview.sh
# 7_merge_Quick96.sh
# 7_merge_SAEHD.sh
# 8_merged_to_avi.sh
# 8_merged_to_mov_lossless.sh
# 8_merged_to_mp4.sh
# 8_merged_to_mp4_lossless.sh
# env.sh

# %% [markdown]
# # Extract Images

# %%
# !bash 2_extract_image_from_data_src.sh
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/mlsteam/lab/workspace/data_src.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 19529854
#     compatible_brands: mp42isom
#     creation_time   : 2018-04-19T07:29:40.000000Z
#   Duration: 00:00:27.36, start: 0.041708, bitrate: 4027 kb/s
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 4025 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       creation_time   : 2018-04-19T07:29:40.000000Z
#       handler_name    : Video Media Handler
#       encoder         : AVC Coding
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/mlsteam/lab/workspace/data_src/%5d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 19529854
#     compatible_brands: mp42isom
#     encoder         : Lavf57.83.100
#     Stream #0:0(eng): Video: png, rgb24, 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 23.98 fps, 23.98 tbn, 23.98 tbc (default)
#     Metadata:
#       creation_time   : 2018-04-19T07:29:40.000000Z
#       handler_name    : Video Media Handler
#       encoder         : Lavc57.107.100 png
# frame=  655 fps= 13 q=-0.0 Lsize=N/A time=00:00:27.31 bitrate=N/A speed=0.562x
# video:501791kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# Done.

# %%
# !bash 3_extract_image_from_data_dst.sh
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/mlsteam/lab/workspace/data_dst.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:54.02, start: 0.000000, bitrate: 15841 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 15705 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/mlsteam/lab/workspace/data_dst/%5d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: png, rgb24, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 png
# frame= 1619 fps= 26 q=-0.0 Lsize=N/A time=00:00:54.02 bitrate=N/A speed=0.857x
# video:687112kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# Done.

# %% [markdown]
# # Extract Facesets

# %%
# !bash 4_data_src_extract_faces_S3FD.sh
# Out:
# Extracting faces...
# Running on GeForce GTX 1080
# 100%|#########################################| 655/655 [06:17<00:00,  1.73it/s]
# -------------------------
# Images found:        655
# Faces detected:      654
# -------------------------
# Done.

# %%
# !bash 5_data_dst_extract_faces_S3FD.sh
# Out:
# Extracting faces...
# Running on GeForce GTX 1080
# 100%|#######################################| 1619/1619 [12:14<00:00,  2.20it/s]
# -------------------------
# Images found:        1619
# Faces detected:      1619
# -------------------------
# Done.
